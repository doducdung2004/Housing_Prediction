# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook'

import os
from PIL import Image
from IPython.display import display

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
duong_dan = "../src/data/processed_data.csv"
df = pd.read_csv(duong_dan)

display(df.head())

df.info()
display(df.describe())

print(df.isnull().sum())
if 'Gia' in df.columns:
    sns.histplot(df['Gia'], kde=True, bins=30)
    plt.title("Phân phối giá nhà")
    plt.xlabel("Giá nhà")
    plt.ylabel("Tần suất")
    plt.show()
else:
    print("Không tìm thấy cột 'Gia' trong dữ liệu.")

corr = df.corr(numeric_only=True)

if corr.shape[1] > 25:
    corr = corr.iloc[:25, :25]

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Ma trận tương quan giữa các đặc trưng")
plt.show()
thu_muc_anh = "../src/data/images"
so_anh = 5

if os.path.exists(thu_muc_anh):
    anh_list = sorted(os.listdir(thu_muc_anh))[:so_anh]

    for ten_anh in anh_list:
        duong_dan_anh = os.path.join(thu_muc_anh, ten_anh)
        try:
            anh = Image.open(duong_dan_anh)
            print(f"Ảnh: {ten_anh}")
            display(anh.resize((300, 200)))
        except Exception as e:
            print(f"Lỗi với ảnh {ten_anh}: {e}")
else:
    print(f"Thư mục ảnh không tồn tại: {thu_muc_anh}")
# Out:
#    Id  DienTich         ViTri  SoPhongNgu  SoWC  SoTang     Gia      KinhDo  \
# 0   1       320       Ba Đình           1     2       3  331464  105.906597
# 1   2       212  Hai Bà Trưng           4     4       3  187143  105.934041
# 2   3       326       Đống Đa           5     2       4  328542  105.840177
# 3   4       300  Hai Bà Trưng           6     1       5  250806  105.922937
# 4   5       215     Long Biên           2     1       3  240400  105.944089
#
#         ViDo       Image  ...      f503      f504      f505      f506  \
# 0  21.012422   anh17.jpg  ...  3.079252  0.181044  0.108693  0.138316
# 1  20.993593  anh100.jpg  ...  1.734644  0.471463  0.451512  0.077239
# 2  21.023107   anh90.jpg  ...  1.448626  0.424014  0.219634  0.295665
# 3  21.025859   anh81.jpg  ...  3.080909  0.457030  0.581043  0.000000
# 4  21.002076   anh86.jpg  ...  1.512267  0.959818  0.157420  0.116655
#
#        f507      f508      f509      f510      f511  ViTri_ma
# ...
